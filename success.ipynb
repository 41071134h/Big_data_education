# %% [markdown]
# <a href="https://colab.research.google.com/github/41071134h/Big_data_education/blob/main/success.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.5/975.5 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.5/127.5 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 1.9 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade langchain

# %%
pip install langchain_community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 22.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 7.2 MB/s eta 0:00:00
# ...

# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
import pandas as pd

# 上傳文件
uploaded = files.upload()

# 讀取並處理上傳的CSV文件
for filename in uploaded.keys():
    # 讀取CSV文件，注意將逗號替換為空白，然後轉換為數字格式
    df = pd.read_csv(io.BytesIO(uploaded[filename]))
    df['Quantity'] = df['Quantity'].str.replace(',', '').astype(float)  # 去除逗號並轉換為浮點數

    # 檢查是否存在'quantity'和'method'列
    if 'Quantity' in df.columns and 'Method' in df.columns:
        # 計算平均數量
        average_quantity = df['Quantity'].mean()

        # 找出使用最多的方法
        most_used_method = df['Method'].value_counts().idxmax()

        # 顯示結果
        print(f"\n文件: {filename}")
        print(f"平均數量: {average_quantity}")
        print(f"使用最多的方法: {most_used_method}")
    else:
        print(f"\n文件: {filename} 不包含 'quantity' 和/或 'method' 列，無法進行分析。")
# Out:
#      <input type="file" id="files-23ac30a7-9c23-4841-b224-418e030d01c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23ac30a7-9c23-4841-b224-418e030d01c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
